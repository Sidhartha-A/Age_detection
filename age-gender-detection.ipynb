# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df_path = '/kaggle/input/utkface-new/UTKFace'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from PIL import Image
import cv2
from sklearn.model_selection import train_test_split

# %%
images = []
age = []
gender = []
for img in os.listdir(df_path):
    ages = img. split("_")[0]
    genders = img. split("_") [1]
    img = cv2.imread(str(df_path)+"/"+str(img))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    images.append(np.array(img))
    age. append(np.array (ages))
    gender.append(np.array(genders))

# %%
age = np.array(age, dtype=np.int64)
images = np.array(images)
gender = np.array(gender, np.uint64)

# %%
X_train_age, X_test_age, y_train_age, y_test_age = train_test_split(images, age, random_state = 42)
X_train_gender, X_test_gender,y_train_gender, y_test_gender = train_test_split(images, gender, random_state = 42)

# %%
images
# Out:
# array([[[[ 17,  11,  11],
#          [ 12,   6,   6],
#          [  9,   5,   6],
#          ...,
#          [ 61,  36,  29],
#          [ 69,  41,  37],
#          [ 70,  42,  38]],
#
#         [[ 17,  11,  11],
#          [ 12,   6,   6],
#          [  8,   4,   5],
#          ...,
#          [ 58,  31,  24],
#          [ 65,  37,  33],
#          [ 67,  39,  35]],
#
#         [[ 20,  14,  14],
#          [ 12,   6,   6],
#          [  6,   2,   3],
#          ...,
#          [ 52,  23,  17],
#          [ 61,  32,  28],
#          [ 66,  37,  33]],
#
#         ...,
#
#         [[ 41,  41,  41],
#          [ 36,  36,  36],
#          [ 28,  28,  28],
#          ...,
#          [  3,   2,   7],
#          [  5,   4,   9],
#          [  6,   5,  10]],
#
#         [[ 44,  44,  44],
#          [ 39,  39,  39],
#          [ 30,  30,  30],
#          ...,
#          [  3,   3,   5],
#          [  6,   6,   8],
#          [  8,   8,  10]],
#
#         [[ 52,  52,  52],
#          [ 46,  46,  46],
#          [ 37,  37,  37],
#          ...,
#          [  3,   3,   5],
#          [  7,   7,   9],
#          [ 10,  10,  12]]],
#
#
#        [[[  0,   4,   7],
#          [  0,   4,   7],
#          [  0,   4,   5],
#          ...,
#          [ 26,  26,  26],
#          [ 32,  30,  31],
#          [ 35,  33,  34]],
#
#         [[  0,   4,   7],
#          [  1,   5,   8],
#          [  1,   5,   6],
#          ...,
#          [ 29,  29,  29],
#          [ 36,  34,  35],
#          [ 39,  37,  38]],
#
#         [[  1,   5,   8],
#          [  1,   5,   8],
#          [  1,   5,   6],
#          ...,
#          [ 34,  34,  36],
#          [ 41,  39,  40],
#          [ 44,  42,  43]],
#
#         ...,
#
#         [[110,  89,  96],
#          [110,  89,  94],
#          [110,  89,  96],
#          ...,
#          [ 87,  67,  66],
#          [ 87,  67,  66],
#          [ 86,  66,  65]],
#
#         [[116,  96, 105],
#          [116,  97, 103],
#          [116,  96, 105],
#          ...,
#          [ 88,  68,  67],
#          [ 88,  68,  67],
#          [ 87,  67,  66]],
#
#         [[121, 101, 110],
#          [121, 101, 110],
#          [121, 101, 110],
#          ...,
#          [ 89,  69,  68],
#          [ 88,  68,  67],
#          [ 88,  68,  67]]],
#
#
#        [[[ 41,  43,  38],
#          [ 39,  41,  36],
#          [ 36,  38,  33],
#          ...,
#          [146, 139, 131],
#          [168, 161, 153],
#          [185, 178, 170]],
#
#         [[ 39,  41,  36],
#          [ 38,  40,  35],
#          [ 36,  38,  33],
#          ...,
#          [142, 135, 127],
#          [164, 157, 149],
#          [182, 175, 167]],
#
#         [[ 37,  39,  34],
#          [ 37,  39,  34],
#          [ 36,  37,  32],
#          ...,
#          [135, 128, 120],
#          [158, 151, 143],
#          [176, 169, 161]],
#
#         ...,
#
#         [[ 18,   7,   3],
#          [ 19,   8,   4],
#          [ 23,  10,   4],
#          ...,
#          [126, 122, 113],
#          [149, 145, 136],
#          [168, 165, 156]],
#
#         [[ 20,   6,   3],
#          [ 21,   7,   4],
#          [ 25,  10,   5],
#          ...,
#          [128, 124, 115],
#          [153, 149, 140],
#          [173, 170, 161]],
#
#         [[ 20,   6,   3],
#          [ 22,   8,   5],
#          [ 25,  10,   5],
#          ...,
#          [131, 127, 118],
#          [156, 152, 143],
#          [177, 174, 165]]],
#
#
#        ...,
#
#
#        [[[205, 185, 174],
#          [206, 186, 175],
#          [206, 186, 175],
#          ...,
#          [165, 145, 110],
#          [165, 145, 110],
#          [165, 145, 110]],
#
#         [[205, 185, 174],
#          [205, 185, 174],
#          [206, 186, 175],
#          ...,
#          [165, 145, 110],
#          [165, 145, 110],
#          [165, 145, 110]],
#
#         [[206, 184, 173],
#          [207, 185, 174],
#          [205, 185, 174],
#          ...,
#          [165, 145, 110],
#          [165, 145, 110],
#          [165, 145, 110]],
#
#         ...,
#
#         [[197, 217, 215],
#          [210, 230, 228],
#          [222, 241, 239],
#          ...,
#          [217, 215, 229],
#          [214, 213, 231],
#          [211, 212, 230]],
#
#         [[219, 238, 236],
#          [225, 244, 242],
#          [228, 247, 245],
#          ...,
#          [215, 217, 230],
#          [212, 215, 232],
#          [211, 214, 231]],
#
#         [[233, 252, 250],
#          [235, 254, 252],
#          [234, 253, 251],
#          ...,
#          [215, 219, 231],
#          [213, 216, 233],
#          [210, 216, 232]]],
#
#
#        [[[133, 110,  56],
#          [135, 112,  58],
#          [138, 113,  59],
#          ...,
#          [226, 229, 208],
#          [222, 225, 204],
#          [220, 223, 202]],
#
#         [[129, 106,  52],
#          [134, 111,  57],
#          [141, 116,  62],
#          ...,
#          [227, 230, 209],
#          [224, 227, 206],
#          [221, 224, 203]],
#
#         [[125, 102,  48],
#          [135, 112,  58],
#          [148, 123,  69],
#          ...,
#          [228, 231, 210],
#          [225, 228, 207],
#          [223, 226, 205]],
#
#         ...,
#
#         [[215, 170, 105],
#          [215, 170, 105],
#          [215, 170, 105],
#          ...,
#          [121,  81,  45],
#          [123,  76,  34],
#          [129,  78,  33]],
#
#         [[218, 170, 104],
#          [219, 171, 105],
#          [220, 172, 106],
#          ...,
#          [123,  85,  49],
#          [121,  76,  35],
#          [126,  77,  34]],
#
#         [[218, 169, 102],
#          [219, 170, 103],
#          [221, 172, 105],
#          ...,
#          [126,  88,  52],
#          [123,  78,  37],
#          [126,  77,  34]]],
#
#
#        [[[244, 248, 249],
#          [246, 247, 249],
#          [253, 247, 251],
#          ...,
#          [114, 120, 136],
#          [114, 120, 136],
#          [114, 120, 136]],
#
#         [[231, 235, 236],
#          [235, 236, 238],
#          [242, 237, 241],
#          ...,
#          [114, 120, 136],
#          [114, 120, 136],
#          [114, 120, 136]],
#
#         [[212, 217, 220],
#          [219, 220, 224],
#          [228, 223, 229],
#          ...,
#          [114, 120, 136],
#          [114, 120, 136],
#          [114, 120, 136]],
#
#         ...,
#
#         [[206, 196, 194],
#          [206, 196, 194],
#          [207, 197, 195],
#          ...,
#          [193, 190, 185],
#          [191, 190, 185],
#          [190, 189, 184]],
#
#         [[206, 196, 194],
#          [205, 195, 193],
#          [205, 195, 193],
#          ...,
#          [193, 190, 185],
#          [191, 190, 185],
#          [191, 190, 185]],
#
#         [[201, 191, 189],
#          [199, 189, 187],
#          [198, 188, 186],
#          ...,
#          [193, 190, 185],
#          [192, 191, 186],
#          [192, 191, 186]]]], dtype=uint8)

# %%
import tensorflow as tf
from keras.models import Sequential, Model, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Dropout
from keras.layers import Activation, Flatten, BatchNormalization

# %%
age_model = Sequential()
age_model.add(Conv2D(128, kernel_size=3, activation='relu', input_shape=(200,200,3)))
#age_model.add(Conv2D(128, kernel_size=3, activation='relu'))
age_model.add(MaxPool2D(pool_size=3, strides=2))

age_model.add(Conv2D(128, kernel_size=3, activation='relu'))
#age_model.add(Conv2D(128, kernel_size=3, activation='relu'))
age_model.add(MaxPool2D(pool_size=3, strides=2))
              
age_model.add(Conv2D(256, kernel_size=3, activation='relu'))
#age_model.add(Conv2D(256, kernel_size=3, activation='relu'))
age_model.add(MaxPool2D(pool_size=3, strides=2))

age_model.add(Conv2D(512, kernel_size=3, activation='relu'))
#age_model.add(Conv2D(512, kernel_size=3, activation='relu'))
age_model.add(MaxPool2D(pool_size=3, strides=2))

age_model.add(Flatten())
age_model.add(Dropout(0.2))
age_model.add(Dense(512, activation='relu'))

age_model.add(Dense(1, activation='linear', name='age'))

# %%
age_model.compile(optimizer='adam', loss='mse', metrics=['mae'])
print(age_model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 198, 198, 128)  │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 98, 98, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 96, 96, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 47, 47, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 45, 45, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 22, 22, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 20, 20, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 9, 9, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 41472)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 41472)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │    21,234,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ age (Dense)                     │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,861,185 (87.21 MB)
#  Trainable params: 22,861,185 (87.21 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
history_age = age_model.fit(X_train_age, y_train_age,
                        validation_data=(X_test_age, y_test_age), epochs=50)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1726486057.794914      83 service.cc:145] XLA service 0x787bb400c840 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1726486057.794973      83 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1726486057.794979      83 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#
50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 64.6805 - mae: 6.0141 - val_loss: 87.4698 - val_mae: 6.6346
# Epoch 29/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 60.2234 - mae: 5.7775 - val_loss: 109.8457 - val_mae: 7.6153
# Epoch 30/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 60.1153 - mae: 5.7893 - val_loss: 95.3424 - val_mae: 7.0234
# Epoch 31/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 53.0096 - mae: 5.4446 - val_loss: 141.4331 - val_mae: 8.4673
# Epoch 32/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 57.0968 - mae: 5.6738 - val_loss: 91.8689 - val_mae: 6.9208
# Epoch 33/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 52.9325 - mae: 5.4819 - val_loss: 93.1950 - val_mae: 7.0010
# Epoch 34/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 54.4636 - mae: 5.5259 - val_loss: 87.2983 - val_mae: 6.7101
# Epoch 35/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 50.9439 - mae: 5.3603 - val_loss: 91.0881 - val_mae: 6.9259
# Epoch 36/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 49.9188 - mae: 5.2896 - val_loss: 98.3258 - val_mae: 7.1566
# Epoch 37/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 47.1017 - mae: 5.1858 - val_loss: 99.0186 - val_mae: 7.0578
# Epoch 38/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 47.4570 - mae: 5.1839 - val_loss: 94.2849 - val_mae: 7.0001
# Epoch 39/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 44.7701 - mae: 5.0554 - val_loss: 93.1170 - val_mae: 6.9008
# Epoch 40/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 40.7631 - mae: 4.8148 - val_loss: 92.4922 - val_mae: 6.9341
# Epoch 41/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 38.9402 - mae: 4.7124 - val_loss: 88.2644 - val_mae: 6.8419
# Epoch 42/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 37.5424 - mae: 4.6769 - val_loss: 90.6115 - val_mae: 6.8283
# Epoch 43/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 37.9840 - mae: 4.6564 - val_loss: 87.3669 - val_mae: 6.6249
# Epoch 44/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 35.6464 - mae: 4.5547 - val_loss: 90.9512 - val_mae: 6.9310
# Epoch 45/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 34.5554 - mae: 4.4234 - val_loss: 89.3105 - val_mae: 6.6975
# Epoch 46/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 33.4166 - mae: 4.3750 - val_loss: 91.2842 - val_mae: 6.8788
# Epoch 47/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 34.9470 - mae: 4.4922 - val_loss: 89.4190 - val_mae: 6.7860
# Epoch 48/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 33.1973 - mae: 4.3614 - val_loss: 88.5841 - val_mae: 6.7945
# Epoch 49/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 29.0085 - mae: 4.0784 - val_loss: 90.6652 - val_mae: 6.8170
# Epoch 50/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 62s 111ms/step - loss: 30.8657 - mae: 4.2007 - val_loss: 87.7508 - val_mae: 6.7676

# %%
predictions = age_model.predict(X_test_gender)
y_pred = (predictions>=0.5).astype(int)[:,0]
# Out:
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step

# %%
gender_model = Sequential()

gender_model.add(Conv2D(36, kernel_size=3, activation='relu', input_shape=(200,200,3)))

gender_model.add(MaxPool2D(pool_size=3, strides=2))
gender_model.add(Conv2D(64, kernel_size=3, activation='relu'))
gender_model.add(MaxPool2D(pool_size=3, strides=2))

gender_model.add(Conv2D(128, kernel_size=3, activation='relu'))
gender_model.add(MaxPool2D(pool_size=3, strides=2))

gender_model.add(Conv2D(256, kernel_size=3, activation='relu'))
gender_model.add(MaxPool2D(pool_size=3, strides=2))

gender_model.add(Conv2D(512, kernel_size=3, activation='relu'))
gender_model.add(MaxPool2D(pool_size=3, strides=2))

gender_model.add(Flatten())
gender_model.add(Dropout(0.2))
gender_model.add(Dense(512, activation='relu'))
gender_model.add(Dense(1, activation='sigmoid', name='gender'))

gender_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.9081 - loss: 0.2069 - val_accuracy: 0.8913 - val_loss: 0.2835
# Epoch 26/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.9164 - loss: 0.1937 - val_accuracy: 0.8871 - val_loss: 0.2692
# Epoch 27/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.9154 - loss: 0.1916 - val_accuracy: 0.8692 - val_loss: 0.2986
# Epoch 28/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.9112 - loss: 0.1982 - val_accuracy: 0.8861 - val_loss: 0.2727
# Epoch 29/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.9217 - loss: 0.1895 - val_accuracy: 0.8846 - val_loss: 0.2664
# Epoch 30/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.9203 - loss: 0.1812 - val_accuracy: 0.8885 - val_loss: 0.2670
# Epoch 31/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.9217 - loss: 0.1769 - val_accuracy: 0.8895 - val_loss: 0.2786
# Epoch 32/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.9199 - loss: 0.1810 - val_accuracy: 0.8746 - val_loss: 0.2980
# Epoch 33/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.9218 - loss: 0.1832 - val_accuracy: 0.8903 - val_loss: 0.2740
# Epoch 34/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.9234 - loss: 0.1691 - val_accuracy: 0.8782 - val_loss: 0.2982
# Epoch 35/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.9232 - loss: 0.1777 - val_accuracy: 0.8812 - val_loss: 0.3204
# Epoch 36/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 44ms/step - accuracy: 0.9232 - loss: 0.1699 - val_accuracy: 0.8832 - val_loss: 0.3019
# Epoch 37/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 44ms/step - accuracy: 0.9323 - loss: 0.1592 - val_accuracy: 0.8853 - val_loss: 0.3212
# Epoch 38/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 44ms/step - accuracy: 0.9204 - loss: 0.1715 - val_accuracy: 0.8868 - val_loss: 0.3204
# Epoch 39/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.9250 - loss: 0.1647 - val_accuracy: 0.8797 - val_loss: 0.2945
# Epoch 40/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 44ms/step - accuracy: 0.9354 - loss: 0.1527 - val_accuracy: 0.8897 - val_loss: 0.3110
# Epoch 41/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 44ms/step - accuracy: 0.9327 - loss: 0.1467 - val_accuracy: 0.8827 - val_loss: 0.2995
# Epoch 42/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 44ms/step - accuracy: 0.9226 - loss: 0.1848 - val_accuracy: 0.8768 - val_loss: 0.2857
# Epoch 43/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.9189 - loss: 0.1663 - val_accuracy: 0.8829 - val_loss: 0.3150
# Epoch 44/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.9318 - loss: 0.1545 - val_accuracy: 0.8773 - val_loss: 0.3034
# Epoch 45/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 44ms/step - accuracy: 0.9296 - loss: 0.1476 - val_accuracy: 0.8897 - val_loss: 0.3232
# Epoch 46/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 44ms/step - accuracy: 0.9355 - loss: 0.1451 - val_accuracy: 0.8829 - val_loss: 0.3181
# Epoch 47/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.9387 - loss: 0.1417 - val_accuracy: 0.8863 - val_loss: 0.3693
# Epoch 48/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.9337 - loss: 0.1449 - val_accuracy: 0.8919 - val_loss: 0.3327
# Epoch 49/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.9355 - loss: 0.1503 - val_accuracy: 0.8922 - val_loss: 0.4019
# Epoch 50/50
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 24s 44ms/step - accuracy: 0.9405 - loss: 0.1337 - val_accuracy: 0.8876 - val_loss: 0.3105

# %%
age_model.save('age_model.h5')

# %%
gender_model.save('gender_model.h5')

# %%
my_model = load_model('gender_model_50epochs.h5', compile=False)


predictions = my_model.predict(X_test_gender)
y_pred = (predictions>= 0.5).astype(int)[:,0]

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(y_test_gender, y_pred))
# Out:
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# Accuracy =  0.887632866542939
